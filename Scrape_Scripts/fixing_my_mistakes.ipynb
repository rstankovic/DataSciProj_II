# %%
'''
I got the correct yearly information, it's just labeled wrong on every single CSV 
so I am going to have to write this script to change every name/create a new file
in a new location and delete the old csv's
'''
# Out:
# "\nI got the correct yearly information, it's just labeled wrong on every single CSV \nso I am going to have to write this script to change every name/create a new file\nin a new location and delete the old csv's\n"

# %%
import os
import pandas as pd
#/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Project 2 Data/IEA_CSVs_raw
#/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Scrape_Scripts/temporary_repository

# %%
countries = []
for file in os.listdir('/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Project 2 Data/IEA_CSVs_raw'):
    print(file)
# Out:
# Germany_2003_Renewables & waste.csv
# Thailand_2001_Renewables & waste.csv
# Belarus_1990_Balances.csv
# Japan_1995_Balances.csv
# Syria_2003_Renewables & waste.csv
# Greece_2004_Renewables & waste.csv
# Iraq_1990_Balances.csv
# Tajikistan_2002_Balances.csv
# Pakistan_2001_Balances.csv
# Spain_1998_Balances.csv
# Serbia_1990_Renewables & waste.csv
# Luxembourg_1991_Balances.csv
# Poland_2003_Renewables & waste.csv
# Lebanon_1992_Renewables & waste.csv
# South Africa_2002_Renewables & waste.csv
# Romania_1999_Renewables & waste.csv
# Zimbabwe_2004_Balances.csv
# Morocco_2004_Balances.csv
# Saudi Arabia_2000_Renewables & waste.csv
# Dominica_1992_Balances.csv
# Uzbekistan_1991_Balances.csv
# Brunei_1990_Balances.csv
# Democratic Republic of the Congo_1999_Balances.csv
# Croatia_1996_Balances.csv
# Eritrea_2003_Balances.csv
# Kuwait_1998_Balances.csv
# Armenia_2003_Renewables & waste.csv
# Gabon_2003_Balances.csv
# Cuba_1999_Balances.csv
# Malta_1996_Balances.csv
# ...

# %%
for file in os.listdir('/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Project 2 Data/IEA_CSVs_raw'):
    fileList = file.split('_')
    country = fileList[0]
    year = int(fileList[1])
    category = fileList[2]
    year += 14
    tempFile = pd.read_csv(f'/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Project 2 Data/IEA_CSVs_raw/{file}')
    tempFile.to_csv(f"/Users/christianstankovic/Desktop/DATA/DataSciProj_II/Scrape_Scripts/temporary_repository/{country}_{year}_{category}.csv")
